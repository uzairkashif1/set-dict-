# %% [markdown]
# #### Dict

# %%
name = { 1 : "(abbas raza)",2 : "umer , usman ",3 : "aar",4 : "malik shb",5 : "ejaz , awan hussain",6 : "uzair kashif" }
marks = {"abbas" : 44, "umer , usman" : 34, "aar" : 32, "malik shb"  : 28, "ejaz , awan hussain" : 26, "uzair kashif" : 22}

# %%
print(name[1])
print(marks["uzair kashif"])
print(type(marks))
# Out:
# (abbas raza)
# 22
# <class 'dict'>

# %%
name.update({"(abbas raza)" : 9})

# %%
print(name)
# Out:
# {1: '(abbas raza)', 2: 'umer , usman ', 3: 'aar', 4: 'malik shb', 5: 'ejaz , awan hussain', 6: 'uzair kashif', '(abbas raza)': 9}

# %%
marks = {"abbas" : 44, "umer , usman" : 34, "aar" : 32, "malik shb"  : 28, "ejaz , awan hussain" : 26, "uzair kashif" : 22}
marks.update({"abbas": 20})
print(marks)
# Out:
# {'abbas': 20, 'umer , usman': 34, 'aar': 32, 'malik shb': 28, 'ejaz , awan hussain': 26, 'uzair kashif': 22}

# %%
name = { 1 : "(abbas raza)",2 : "umer , usman ",3 : "aar",4 : "malik shb",5 : "ejaz , awan hussain",6 : "uzair kashif" }
name.pop(1)
# Out:
# '(abbas raza)'

# %%
print(name)
# Out:
# {2: 'umer , usman ', 3: 'aar', 4: 'malik shb', 5: 'ejaz , awan hussain', 6: 'uzair kashif'}

# %% [markdown]
# ### Set

# %%
x = (1,2,3,4,5)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x1 = set(x)

# %%
print(x1)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(type(x1))
# Out:
# <class 'set'>
